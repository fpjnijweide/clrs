# %%
import pandas as pd

df = pd.read_csv('clrs_paper_results.csv')
with open("results.txt") as myfile:
    results_txt = myfile.read()

# %%
df
# Out:
#                  Algorithm  Deep Sets  Deep Sets STD    GAT  GAT STD  Memnet  \
# 0        Activity Selector      66.09           1.67  73.23     1.37   24.10
# 1      Articulation Points      39.06           4.04  37.76     1.62    1.50
# 2             Bellman-Ford      51.33           0.85  87.91     1.19   40.04
# 3                      BFS      98.63           0.38  99.04     0.21   43.34
# 4            Binary Search      47.97           0.88  23.50     3.12   14.37
# 5                  Bridges      32.43           2.65  25.64     6.60   30.26
# 6              Bubble Sort      50.73           3.24   9.91     1.77   73.58
# 7       DAG Shortest Paths      73.21           2.42  81.14     1.37   66.15
# 8                      DFS       7.44           0.73  11.78     2.04   13.36
# 9                 Dijkstra      36.12           3.10  58.01     0.79   22.48
# 10      Find Max. Subarray      12.48           0.39  24.43     0.43   13.05
# 11          Floyd-Warshall       7.22           0.90  16.66     3.14   14.17
# 12             Graham Scan      64.71           2.75  77.89     2.70   40.62
# 13                Heapsort      28.94          12.57  10.35     1.83   68.00
# 14          Insertion Sort      40.98           4.65  29.52     1.87   71.42
# 15           Jarvis' March      50.25           0.81  51.51    10.25   22.99
# 16             KMP Matcher       3.22           0.54   3.03     0.36    1.81
# 17              LCS Length      50.10           5.25  57.88     1.02   49.84
# 18      Matrix Chain Order      78.36           3.58  78.19     3.31   81.96
# 19                 Minimum      80.19           2.08  84.20     2.95   86.93
# 20             MST-Kruskal      60.58           4.71  65.72     0.99   28.84
# 21                MST-Prim      12.17           5.47  38.20     4.34   10.29
# 22  Na\"{i}ve String Match       2.05           0.29   3.01     1.20    1.22
# 23             Optimal BST      69.71           1.36  65.49     1.75   72.03
# 24             Quickselect       3.21           1.33   4.36     0.95    1.74
# 25               Quicksort      37.74           2.16   7.60     0.98   73.10
# 26      Segments Intersect      77.29           0.60  90.41     0.04   71.81
# 27                     SCC      17.81           2.61  12.70     3.12   16.32
# 28         Task Scheduling      84.84           0.70  84.69     2.09   82.74
# 29        Topological Sort      15.84           3.57  27.03     6.92    2.73
# 30         Overall average      43.36           0.00  44.69     0.00   38.03
#
#     Memnet STD   MPNN  MPNN STD    PGN  PGN STD
# 0         2.22  80.66      3.16  66.80     1.62
# 1         0.61  50.91      2.18  49.53     2.09
# 2         1.46  92.01      0.28  92.99     0.34
# 3         0.04  99.89      0.05  99.63     0.29
# 4         0.46  36.83      0.26  76.95     0.13
# 5         0.05  72.69      4.78  51.42     7.82
# 6         0.78   5.27      0.60   6.01     1.95
# 7         1.92  96.24      0.56  96.94     0.16
# 8         1.61   6.54      0.51   8.71     0.24
# 9         2.39  91.50      0.50  83.45     1.75
# 10        0.08  20.30      0.49  65.23     2.56
# 11        0.13  26.74      1.77  28.76     0.51
# 12        2.31  91.04      0.31  56.87     1.61
# 13        1.57  10.94      0.84   5.27     0.18
# 14        0.86  19.81      2.08  44.37     2.43
# 15        3.87  34.86     12.39  49.19     1.07
# 16        0.00   2.49      0.86   2.00     0.12
# 17        4.34  53.23      0.36  56.82     0.21
# 18        1.03  79.84      1.40  83.91     0.49
# 19        0.11  85.34      0.88  87.71     0.52
# 20        0.61  70.97      1.50  66.96     1.36
# 21        3.77  69.08      7.56  63.33     0.98
# 22        0.48   3.92      0.30   2.08     0.20
# 23        1.21  62.23      0.44  71.01     1.82
# 24        0.03   1.43      0.69   3.66     0.42
# 25        0.67  11.30      0.10   6.17     0.15
# 26        0.90  93.44      0.10  77.51     0.75
# 27        4.78  24.37      4.88  20.80     0.64
# 28        0.04  84.11      0.32  84.89     0.91
# 29        0.11  52.60      6.24  60.45     2.69
# 30        0.00  51.02      0.00  52.31     0.00

# %%
networks = ["GAT","MPNN","PGN"]
networks_code_list = ["gatv2", "mpnn", "pgn"]
networks_colors = ["red","blue","green"]

for network in networks:
    df[f"{network} Upper Bound"] = df[network] + df[f"{network} STD"]
    df[f"{network} Lower Bound"] = df[network] - df[f"{network} STD"]

df
# Out:
#                  Algorithm  Deep Sets  Deep Sets STD    GAT  GAT STD  Memnet  \
# 0        Activity Selector      66.09           1.67  73.23     1.37   24.10
# 1      Articulation Points      39.06           4.04  37.76     1.62    1.50
# 2             Bellman-Ford      51.33           0.85  87.91     1.19   40.04
# 3                      BFS      98.63           0.38  99.04     0.21   43.34
# 4            Binary Search      47.97           0.88  23.50     3.12   14.37
# 5                  Bridges      32.43           2.65  25.64     6.60   30.26
# 6              Bubble Sort      50.73           3.24   9.91     1.77   73.58
# 7       DAG Shortest Paths      73.21           2.42  81.14     1.37   66.15
# 8                      DFS       7.44           0.73  11.78     2.04   13.36
# 9                 Dijkstra      36.12           3.10  58.01     0.79   22.48
# 10      Find Max. Subarray      12.48           0.39  24.43     0.43   13.05
# 11          Floyd-Warshall       7.22           0.90  16.66     3.14   14.17
# 12             Graham Scan      64.71           2.75  77.89     2.70   40.62
# 13                Heapsort      28.94          12.57  10.35     1.83   68.00
# 14          Insertion Sort      40.98           4.65  29.52     1.87   71.42
# 15           Jarvis' March      50.25           0.81  51.51    10.25   22.99
# 16             KMP Matcher       3.22           0.54   3.03     0.36    1.81
# 17              LCS Length      50.10           5.25  57.88     1.02   49.84
# 18      Matrix Chain Order      78.36           3.58  78.19     3.31   81.96
# 19                 Minimum      80.19           2.08  84.20     2.95   86.93
# 20             MST-Kruskal      60.58           4.71  65.72     0.99   28.84
# 21                MST-Prim      12.17           5.47  38.20     4.34   10.29
# 22  Na\"{i}ve String Match       2.05           0.29   3.01     1.20    1.22
# 23             Optimal BST      69.71           1.36  65.49     1.75   72.03
# 24             Quickselect       3.21           1.33   4.36     0.95    1.74
# 25               Quicksort      37.74           2.16   7.60     0.98   73.10
# 26      Segments Intersect      77.29           0.60  90.41     0.04   71.81
# 27                     SCC      17.81           2.61  12.70     3.12   16.32
# 28         Task Scheduling      84.84           0.70  84.69     2.09   82.74
# 29        Topological Sort      15.84           3.57  27.03     6.92    2.73
# 30         Overall average      43.36           0.00  44.69     0.00   38.03
#
#     Memnet STD   MPNN  MPNN STD    PGN  PGN STD  GAT Upper Bound  \
# 0         2.22  80.66      3.16  66.80     1.62            74.60
# 1         0.61  50.91      2.18  49.53     2.09            39.38
# 2         1.46  92.01      0.28  92.99     0.34            89.10
# 3         0.04  99.89      0.05  99.63     0.29            99.25
# 4         0.46  36.83      0.26  76.95     0.13            26.62
# 5         0.05  72.69      4.78  51.42     7.82            32.24
# 6         0.78   5.27      0.60   6.01     1.95            11.68
# 7         1.92  96.24      0.56  96.94     0.16            82.51
# 8         1.61   6.54      0.51   8.71     0.24            13.82
# 9         2.39  91.50      0.50  83.45     1.75            58.80
# 10        0.08  20.30      0.49  65.23     2.56            24.86
# 11        0.13  26.74      1.77  28.76     0.51            19.80
# 12        2.31  91.04      0.31  56.87     1.61            80.59
# 13        1.57  10.94      0.84   5.27     0.18            12.18
# 14        0.86  19.81      2.08  44.37     2.43            31.39
# 15        3.87  34.86     12.39  49.19     1.07            61.76
# 16        0.00   2.49      0.86   2.00     0.12             3.39
# 17        4.34  53.23      0.36  56.82     0.21            58.90
# 18        1.03  79.84      1.40  83.91     0.49            81.50
# 19        0.11  85.34      0.88  87.71     0.52            87.15
# 20        0.61  70.97      1.50  66.96     1.36            66.71
# 21        3.77  69.08      7.56  63.33     0.98            42.54
# 22        0.48   3.92      0.30   2.08     0.20             4.21
# 23        1.21  62.23      0.44  71.01     1.82            67.24
# 24        0.03   1.43      0.69   3.66     0.42             5.31
# 25        0.67  11.30      0.10   6.17     0.15             8.58
# 26        0.90  93.44      0.10  77.51     0.75            90.45
# 27        4.78  24.37      4.88  20.80     0.64            15.82
# 28        0.04  84.11      0.32  84.89     0.91            86.78
# 29        0.11  52.60      6.24  60.45     2.69            33.95
# 30        0.00  51.02      0.00  52.31     0.00            44.69
#
#     GAT Lower Bound  MPNN Upper Bound  MPNN Lower Bound  PGN Upper Bound  \
# 0             71.86             83.82             77.50            68.42
# 1             36.14             53.09             48.73            51.62
# 2             86.72             92.29             91.73            93.33
# 3             98.83             99.94             99.84            99.92
# 4             20.38             37.09             36.57            77.08
# 5             19.04             77.47             67.91            59.24
# 6              8.14              5.87              4.67             7.96
# 7             79.77             96.80             95.68            97.10
# 8              9.74              7.05              6.03             8.95
# 9             57.22             92.00             91.00            85.20
# 10            24.00             20.79             19.81            67.79
# 11            13.52             28.51             24.97            29.27
# 12            75.19             91.35             90.73            58.48
# 13             8.52             11.78             10.10             5.45
# 14            27.65             21.89             17.73            46.80
# 15            41.26             47.25             22.47            50.26
# 16             2.67              3.35              1.63             2.12
# 17            56.86             53.59             52.87            57.03
# 18            74.88             81.24             78.44            84.40
# 19            81.25             86.22             84.46            88.23
# 20            64.73             72.47             69.47            68.32
# 21            33.86             76.64             61.52            64.31
# 22             1.81              4.22              3.62             2.28
# 23            63.74             62.67             61.79            72.83
# 24             3.41              2.12              0.74             4.08
# 25             6.62             11.40             11.20             6.32
# 26            90.37             93.54             93.34            78.26
# 27             9.58             29.25             19.49            21.44
# 28            82.60             84.43             83.79            85.80
# 29            20.11             58.84             46.36            63.14
# 30            44.69             51.02             51.02            52.31
#
#     PGN Lower Bound
# 0             65.18
# 1             47.44
# 2             92.65
# 3             99.34
# 4             76.82
# 5             43.60
# 6              4.06
# 7             96.78
# 8              8.47
# 9             81.70
# 10            62.67
# 11            28.25
# 12            55.26
# 13             5.09
# 14            41.94
# 15            48.12
# 16             1.88
# 17            56.61
# 18            83.42
# 19            87.19
# 20            65.60
# 21            62.35
# 22             1.88
# 23            69.19
# 24             3.24
# 25             6.02
# 26            76.76
# 27            20.16
# 28            83.98
# 29            57.76
# 30            52.31

# %%
import re
import numpy as np

algorithm_names = list(df['Algorithm'])

algorithms_code_list = [
    'articulation_points',
    'activity_selector',
    'bellman_ford',
    'bfs',
    'binary_search',
    'bridges',
    'bubble_sort',
    'dag_shortest_paths',
    'dfs',
    'dijkstra',
    'find_maximum_subarray_kadane',
    'floyd_warshall',
    'graham_scan',
    'heapsort',
    'insertion_sort',
    'jarvis_march',
    'kmp_matcher',
    'lcs_length',
    'matrix_chain_order',
    'minimum',
    'mst_kruskal',
    'mst_prim',
    'naive_string_matcher',
    'optimal_bst',
    'quickselect',
    'quicksort',
    'segments_intersect',
    'strongly_connected_components',
    'task_scheduling',
    'topological_sort',
]

memory_types = ["NTM"]

memory_sizes= [[20,100]   ]

results_lines=results_txt.splitlines()

# %%
df
# Out:
#                  Algorithm  Deep Sets  Deep Sets STD    GAT  GAT STD  Memnet  \
# 0        Activity Selector      66.09           1.67  73.23     1.37   24.10
# 1      Articulation Points      39.06           4.04  37.76     1.62    1.50
# 2             Bellman-Ford      51.33           0.85  87.91     1.19   40.04
# 3                      BFS      98.63           0.38  99.04     0.21   43.34
# 4            Binary Search      47.97           0.88  23.50     3.12   14.37
# 5                  Bridges      32.43           2.65  25.64     6.60   30.26
# 6              Bubble Sort      50.73           3.24   9.91     1.77   73.58
# 7       DAG Shortest Paths      73.21           2.42  81.14     1.37   66.15
# 8                      DFS       7.44           0.73  11.78     2.04   13.36
# 9                 Dijkstra      36.12           3.10  58.01     0.79   22.48
# 10      Find Max. Subarray      12.48           0.39  24.43     0.43   13.05
# 11          Floyd-Warshall       7.22           0.90  16.66     3.14   14.17
# 12             Graham Scan      64.71           2.75  77.89     2.70   40.62
# 13                Heapsort      28.94          12.57  10.35     1.83   68.00
# 14          Insertion Sort      40.98           4.65  29.52     1.87   71.42
# 15           Jarvis' March      50.25           0.81  51.51    10.25   22.99
# 16             KMP Matcher       3.22           0.54   3.03     0.36    1.81
# 17              LCS Length      50.10           5.25  57.88     1.02   49.84
# 18      Matrix Chain Order      78.36           3.58  78.19     3.31   81.96
# 19                 Minimum      80.19           2.08  84.20     2.95   86.93
# 20             MST-Kruskal      60.58           4.71  65.72     0.99   28.84
# 21                MST-Prim      12.17           5.47  38.20     4.34   10.29
# 22  Na\"{i}ve String Match       2.05           0.29   3.01     1.20    1.22
# 23             Optimal BST      69.71           1.36  65.49     1.75   72.03
# 24             Quickselect       3.21           1.33   4.36     0.95    1.74
# 25               Quicksort      37.74           2.16   7.60     0.98   73.10
# 26      Segments Intersect      77.29           0.60  90.41     0.04   71.81
# 27                     SCC      17.81           2.61  12.70     3.12   16.32
# 28         Task Scheduling      84.84           0.70  84.69     2.09   82.74
# 29        Topological Sort      15.84           3.57  27.03     6.92    2.73
# 30         Overall average      43.36           0.00  44.69     0.00   38.03
#
#     Memnet STD   MPNN  MPNN STD    PGN  PGN STD  GAT Upper Bound  \
# 0         2.22  80.66      3.16  66.80     1.62            74.60
# 1         0.61  50.91      2.18  49.53     2.09            39.38
# 2         1.46  92.01      0.28  92.99     0.34            89.10
# 3         0.04  99.89      0.05  99.63     0.29            99.25
# 4         0.46  36.83      0.26  76.95     0.13            26.62
# 5         0.05  72.69      4.78  51.42     7.82            32.24
# 6         0.78   5.27      0.60   6.01     1.95            11.68
# 7         1.92  96.24      0.56  96.94     0.16            82.51
# 8         1.61   6.54      0.51   8.71     0.24            13.82
# 9         2.39  91.50      0.50  83.45     1.75            58.80
# 10        0.08  20.30      0.49  65.23     2.56            24.86
# 11        0.13  26.74      1.77  28.76     0.51            19.80
# 12        2.31  91.04      0.31  56.87     1.61            80.59
# 13        1.57  10.94      0.84   5.27     0.18            12.18
# 14        0.86  19.81      2.08  44.37     2.43            31.39
# 15        3.87  34.86     12.39  49.19     1.07            61.76
# 16        0.00   2.49      0.86   2.00     0.12             3.39
# 17        4.34  53.23      0.36  56.82     0.21            58.90
# 18        1.03  79.84      1.40  83.91     0.49            81.50
# 19        0.11  85.34      0.88  87.71     0.52            87.15
# 20        0.61  70.97      1.50  66.96     1.36            66.71
# 21        3.77  69.08      7.56  63.33     0.98            42.54
# 22        0.48   3.92      0.30   2.08     0.20             4.21
# 23        1.21  62.23      0.44  71.01     1.82            67.24
# 24        0.03   1.43      0.69   3.66     0.42             5.31
# 25        0.67  11.30      0.10   6.17     0.15             8.58
# 26        0.90  93.44      0.10  77.51     0.75            90.45
# 27        4.78  24.37      4.88  20.80     0.64            15.82
# 28        0.04  84.11      0.32  84.89     0.91            86.78
# 29        0.11  52.60      6.24  60.45     2.69            33.95
# 30        0.00  51.02      0.00  52.31     0.00            44.69
#
#     GAT Lower Bound  MPNN Upper Bound  MPNN Lower Bound  PGN Upper Bound  \
# 0             71.86             83.82             77.50            68.42
# 1             36.14             53.09             48.73            51.62
# 2             86.72             92.29             91.73            93.33
# 3             98.83             99.94             99.84            99.92
# 4             20.38             37.09             36.57            77.08
# 5             19.04             77.47             67.91            59.24
# 6              8.14              5.87              4.67             7.96
# 7             79.77             96.80             95.68            97.10
# 8              9.74              7.05              6.03             8.95
# 9             57.22             92.00             91.00            85.20
# 10            24.00             20.79             19.81            67.79
# 11            13.52             28.51             24.97            29.27
# 12            75.19             91.35             90.73            58.48
# 13             8.52             11.78             10.10             5.45
# 14            27.65             21.89             17.73            46.80
# 15            41.26             47.25             22.47            50.26
# 16             2.67              3.35              1.63             2.12
# 17            56.86             53.59             52.87            57.03
# 18            74.88             81.24             78.44            84.40
# 19            81.25             86.22             84.46            88.23
# 20            64.73             72.47             69.47            68.32
# 21            33.86             76.64             61.52            64.31
# 22             1.81              4.22              3.62             2.28
# 23            63.74             62.67             61.79            72.83
# 24             3.41              2.12              0.74             4.08
# 25             6.62             11.40             11.20             6.32
# 26            90.37             93.54             93.34            78.26
# 27             9.58             29.25             19.49            21.44
# 28            82.60             84.43             83.79            85.80
# 29            20.11             58.84             46.36            63.14
# 30            44.69             51.02             51.02            52.31
#
#     PGN Lower Bound
# 0             65.18
# 1             47.44
# 2             92.65
# 3             99.34
# 4             76.82
# 5             43.60
# 6              4.06
# 7             96.78
# 8              8.47
# 9             81.70
# 10            62.67
# 11            28.25
# 12            55.26
# 13             5.09
# 14            41.94
# 15            48.12
# 16             1.88
# 17            56.61
# 18            83.42
# 19            87.19
# 20            65.60
# 21            62.35
# 22             1.88
# 23            69.19
# 24             3.24
# 25             6.02
# 26            76.76
# 27            20.16
# 28            83.98
# 29            57.76
# 30            52.31

# %%
GAT_BEST = [
    'dfs',
    # 'jarvis_march',
    'kmp_matcher',
    'lcs_length',
    'quickselect',
    'task_scheduling'
]
# MPNN algos
MPNN_BEST = [
    'articulation_points',
    'activity_selector',
    'bfs',
    'bridges',
    'dijkstra',
    'graham_scan',
    'mst_kruskal',
    'mst_prim',
    'naive_string_matcher',
    'segments_intersect',
    'strongly_connected_components',
]
PGN_best = [
    'activity_selector',
    'bellman_ford',
    'binary_search',
    'dag_shortest_paths',
    'find_maximum_subarray_kadane',
    'floyd_warshall',
    'matrix_chain_order',
    'minimum',
    'mst_prim',
    'optimal_bst',
    'quickselect',
    'strongly_connected_components',
    'task_scheduling',
    'topological_sort',
]

import matplotlib.pyplot as plt

marker_list=['o','x','^','d']


for algorithm_index in range(30):
    plt.figure(algorithm_index,figsize=(8, 6), dpi=80) # Here's the part I need
    algorithm_name = algorithm_names[algorithm_index]
    plt.title(algorithm_name)
    plt.ylim([0,100])
    algorithm_code = algorithms_code_list[algorithm_index]
    if algorithm_code in GAT_BEST:
        yy = [df['GAT Upper Bound'][algorithm_index], df['GAT Lower Bound'][algorithm_index]]
        plt.hlines(yy,xmin=0,xmax=100,colors=['red'],linestyles=['dotted'],label='GAT SOTA')

    if algorithm_code in MPNN_BEST:
        yy = [df['MPNN Upper Bound'][algorithm_index], df['MPNN Lower Bound'][algorithm_index]]
        plt.hlines(yy,xmin=0,xmax=100,colors=['blue'],linestyles=['dotted'],label='MPNN SOTA')

    if algorithm_code in PGN_best:
        yy = [df['PGN Upper Bound'][algorithm_index], df['PGN Lower Bound'][algorithm_index]]
        plt.hlines(yy,xmin=0,xmax=100,colors=['green'],linestyles=['dotted'],label='PGN SOTA')

    for network_idx in range(len(networks_code_list)):
        network_name = networks[network_idx]
        network_code = networks_code_list[network_idx]
        network_color = networks_colors[network_idx]
        for memory_idx in range(len(memory_types)):
            memory_type=memory_types[memory_idx]
            memory_size_list = memory_sizes[memory_idx]
            marker = marker_list[memory_idx]
            x = []
            x_last = []
            y = []
            y_last = []
            for memory_size in memory_size_list:
                string_type_1 = f"{algorithm_code}_best_{network_code}_{memory_type}_{memory_size}"
                string_type_2 = f"{algorithm_code}_{network_code}_{memory_type}_{memory_size}_best"
                string_type_last = f"{algorithm_code}_{network_code}_{memory_type}_{memory_size}_last"
                resulting_lines = [line for line in results_lines if (string_type_1 in line or string_type_2 in line or string_type_last in line)]
                last_lines = [line for line in results_lines if (string_type_last in line)]
                if len(resulting_lines)>0:
                    best_line = resulting_lines[0]
                    p = re.compile(r"'score': (.*?),")
                    best_score = p.findall(best_line)[0]
                    col_name = f"{network_name} {memory_type} {memory_size} Best"
                    # if col_name not in df:
                    #     df[col_name] = np.nan
                    # df.loc[algorithm_index, col_name] = best_score
                    x.append(memory_size)
                    y.append(float(best_score)*100)
                if len(last_lines)>0:
                    last_line=last_lines[0]
                    p = re.compile(r"'score': (.*?),")
                    last_score = p.findall(last_line)[0]
                    col_name = f"{network_name} {memory_type} {memory_size} Last"
                    # if col_name not in df:
                    #     df[col_name] = np.nan
                    # df.loc[algorithm_index,col_name] = last_score
                    x_last.append(memory_size)
                    y_last.append(float(last_score)*100)
            # print(x,y)
            if len(x)>0:
                plt.scatter(x,y,marker=marker,s=50,color=network_color,label=f"{network_name} {memory_type}")
                plt.scatter(x_last,y_last,marker=marker,s=25,color=network_color)
    plt.xlabel("Memory size")
    plt.ylabel("Performance in %")
    plt.legend()
    plt.show()

# TODO legend
# TODO figure size
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
